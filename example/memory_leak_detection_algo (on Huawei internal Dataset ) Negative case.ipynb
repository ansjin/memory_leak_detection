# %% [markdown]
# # Memory Leak Detection

# %%
import sys
sys.path.append('../')
from mem_leak_detection import MemLeakDetectionAlgorithm
from mem_leak_detection import MemLeakDetectionAlgorithmPolyFit
from mem_leak_detection import MemLeakDetectionAlgorithmChangePoints
from mem_leak_detection import Precog
import pandas as pd
# required only for ploting
import matplotlib.pyplot as plt
# %matplotlib inline 
from pylab import rcParams
rcParams['figure.figsize']= 15,6
import xlrd

# %%
import glob

# %%
path = '/mnt/datasets/metrics/memleak_negative'
memleak_negative_files = [f for f in glob.glob(path + "**/**/*.xlsx", recursive=True)]
path2 = '/mnt/datasets/metrics/memleak_positive'
memleak_positive_files = [f for f in glob.glob(path2 + "**/**/*.xlsx", recursive=True)]

# %%
len(memleak_negative_files)
# Out:
# 55

# %% [markdown]
# -yellow graphs are good(true negative) <br>
# -blue are false negative

# %%
i = 0
for file in memleak_negative_files:
    i = i +1
    if file =="#####.xlsx":
        continue
    if(len(pd.ExcelFile(file).sheet_names) > 1):
        xls = xlrd.open_workbook(file, on_demand=True)
        print(file)
        if "Train Data" in xls.sheet_names():
            dataset_train = pd.read_excel(file, "Train Data")
        elif "Sheet1" in xls.sheet_names():
            dataset_train = pd.read_excel(file, "Sheet1")
        else:
            dataset_train = pd.read_excel(file, "Data Train")
        dataset_test = pd.read_excel(file, "Test Data")
        dataset_train['Timestamp'] =  pd.to_datetime(dataset_train['Timestamp'], unit='s')
        dataset_test['Timestamp'] =  pd.to_datetime(dataset_test['Timestamp'], unit='s')
        dataset_train.set_index('Timestamp', inplace=True)
        dataset_test.set_index('Timestamp', inplace=True)
        #dataset = dataset.resample("1ms").median()
        #dataset.dropna(inplace=True)
        p1 = Precog()
        p1 = p1.fit(dataset_train.Value)
        plt.figure(figsize=(15,6))
        plt.subplot(221)
        plt.ylim(0,100)
        for xc in p1.change_point_indexes:
            plt.axvline(x=xc)
        for series in p1.fit_trends:
            plt.plot(series,'--', linewidth=3, color='red', label='Trends on Training Data')
        plt.plot(dataset_train.Value, color='green', label='Training Data' )
        plt.legend()
        #plt.scatter(dataset.query('label == 1').index, dataset.query('label == 1').mem_util_percent.values,marker='o', color='red' )
        
        points = p1.predict(dataset_test.Value)
        if(len(points) > 0):
            timestamps = [pd.to_datetime(x.timestamp, unit="ms") for x in points[0].points]
            anomalies = [x.value for x in points[0].points]
            df = pd.DataFrame({'timestamp': timestamps, 'values': anomalies})
            df.set_index("timestamp", inplace=True)    
            
            plt.subplot(222) 
            plt.ylim(0,100)
            for xc in p1.change_point_indexes_predict:
                plt.axvline(x=xc)
            #plt.plot(p1.prediction_trend,'--', linewidth=3, color='red', label='Prediction Trend on Test Data')
            plt.plot(dataset_test.Value, color='blue', label='Test Data')
            plt.plot(df, color='red', label='Found Trend in Test Data')
            plt.legend()
            #plt.scatter(dataset.query('label == 1').index, dataset.query('label == 1').mem_util_percent.values,marker='o', color='red' )
        else:
            plt.subplot(222) 
            plt.ylim(0,100)
            for xc in p1.change_point_indexes_predict:
                plt.axvline(x=xc)
            plt.plot(dataset_test.Value, color='yellow', label='Test Data without any found trend' )  
            plt.legend()
    else:
        continue
# Out:
# /mnt/datasets/iforesight/metrics/memleak_negative/sn_e91723af-897e-4a79-bef9-0a3b7ac3a92d/mem0520_7d.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/sn_594f5bc8-399b-4912-a45d-3cbf16482157/mem0520_7d.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/sn_22018a21-8ff6-439d-b503-6de6fee64305/mem0520_7d.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/sn_1e2cfcf8-71d9-4f9f-94b5-9b8e55a21c75/mem0520_7d.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak67/cmc_false_positive.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak66/cdn_false_positive.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak65/FPdata10.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak64/FPdata5.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak63/FPdata12.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak62/FPdata7.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak61/FPdata13.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak60/FPdata14.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak59/FPdata11.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak58/FPdata6.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak57/FPdata9.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak56/FPdata3.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak55/FPdata2.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak54/FPdata1.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak48/TPdata25.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak46/TPdata21.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak45/TPdata20.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak39/TPdata14.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak36/TPdata10.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak34/TPdata8.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak33/TPdata4.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak31/TPdata2.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak29/mem0520_7d.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak27/mem0520_7d.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak26/1997ea7e-f837-4dde-983a-0b4f89432d98__mem_util.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak25/mem0520_7d.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak24/19964aad-a2ac-4ef3-ae4c-b2cf12befac4__mem_util.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak23/15b705b0-a638-4be9-88af-52d96e27fc48__mem_util.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak22/01d306f2-520c-422a-98bc-471484156b07__mem_util.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak21/01c87d6f-77ea-4a3d-97d4-b018c7f5c422__mem_util.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak20/0b73ea35-18a8-43de-b997-dc0781885fb5__mem_util.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak14/000ed1d6-ab4d-44a3-833c-c66d19c3c381__mem_util.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak13/mem0520_7d.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak12/0301244f-d989-43e7-accf-9a529455915c__mem_util.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak10/09f533b8-59c0-414b-a461-2e052298d065__mem_util.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak05/mem0520_7d.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak02/0367f321-9e73-40c1-8b0a-5683b6787cff__mem_util.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak68/memory.usage_data.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak69/memory.usage_data (1).xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak70/memory.usage_data.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak71/memory.usage_data.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/20191119_1/20191119_1.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/20191119_2/20191119_2.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak72/20191216-EVS-memory.xlsx
# /mnt/datasets/iforesight/metrics/memleak_negative/memleak52/TPdata29.xlsx
